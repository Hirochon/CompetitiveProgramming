# %%
# !pip list
# Out:
# Package                Version
# ---------------------- -------------------
# alembic                1.4.1
# async-generator        1.10
# attrs                  19.3.0
# backcall               0.1.0
# beautifulsoup4         4.8.2
# bleach                 3.1.3
# blinker                1.4
# bokeh                  1.4.0
# certifi                2019.11.28
# certipy                0.1.3
# cffi                   1.14.0
# chardet                3.0.4
# click                  7.1.1
# cloudpickle            1.3.0
# conda                  4.8.2
# conda-package-handling 1.6.0
# cryptography           2.8
# cycler                 0.10.0
# Cython                 0.29.15
# cytoolz                0.10.1
# dask                   2.11.0
# decorator              4.4.2
# defusedxml             0.6.0
# dill                   0.3.1.1
# distributed            2.12.0
# entrypoints            0.3
# fsspec                 0.6.2
# h5py                   2.10.0
# HeapDict               1.0.1
# ...

# %% [markdown]
# ## A問題

# %%
import numpy as np

a, b = map(int, input().split())
# Out:
# 2 4
# 8
